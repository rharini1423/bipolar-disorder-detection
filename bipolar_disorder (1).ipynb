# %%
import pandas as pd
ds=pd.read_csv("/content/Bipolarf.csv")
ds
# Out:
#                Name  Age  Gender  Little interest in work  Feeling hopeless    \
# 0               Aaa   16  Female                        1                   2
# 1     Abhinivesh S    19    Male                        1                   1
# 2         Abhishek    15    Male                        1                   1
# 3         Abinaya S   16  Female                        3                   1
# 4         Abinaya S   19  Female                        1                   1
# ..              ...  ...     ...                      ...                 ...
# 62           Swetha   19  Female                        2                   2
# 63          Varsha    17  Female                        3                   3
# 64    Vishnupriya.S   20  Female                        1                   1
# 65        Visruthi    17  Female                        2                   3
# 66  Visweswara S M    20    Male                        3                   1
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Name                                67 non-null     object
#  1   Age                                 67 non-null     int64
#  2   Gender                              67 non-null     object
#  3   Little interest in work             67 non-null     int64
#  4   Feeling hopeless                    67 non-null     int64
#  5   Feeling angry than usual            67 non-null     int64
#  6   high energy                         67 non-null     int64
#  7   doing more risky things             67 non-null     int64
#  8   Feeling nervous                     67 non-null     int64
#  9   panic                               67 non-null     int64
#  10  Avoiding anxious situations         67 non-null     int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds['Gender']=le.fit_transform(ds['Gender'])
ds['Gender']=pd.DataFrame(ds['Gender'])

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Name                                67 non-null     object
#  1   Age                                 67 non-null     int64
#  2   Gender                              67 non-null     int64
#  3   Little interest in work             67 non-null     int64
#  4   Feeling hopeless                    67 non-null     int64
#  5   Feeling angry than usual            67 non-null     int64
#  6   high energy                         67 non-null     int64
#  7   doing more risky things             67 non-null     int64
#  8   Feeling nervous                     67 non-null     int64
#  9   panic                               67 non-null     int64
#  10  Avoiding anxious situations         67 non-null     int64
# ...

# %%
sums=ds.sum(axis=1)
# Out:
# <ipython-input-6-93ab1f416720>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sums=ds.sum(axis=1)

# %%
print("Sno--Score")
print(sums)
# Out:
# Sno--Score
# 0      85
# 1     107
# 2      83
# 3      87
# 4      96
#      ...
# 62    128
# 63    123
# 64     98
# 65    126
# 66    103
# Length: 67, dtype: int64

# %%
tot=0
for i in sums:
    tot=tot+i
    res=tot/67

print(res)
# Out:
# 97.77611940298507

# %%
thres=97.7;
if thres > 97.7:
    printf("You should consult the Doctor")

# %%
for i in sums:
    if i>thres:
        print(i)
# Out:
# 107
# 107
# 128
# 100
# 115
# 121
# 105
# 104
# 120
# 119
# 101
# 117
# 108
# 124
# 102
# 137
# 112
# 115
# 112
# 113
# 109
# 104
# 99
# 145
# 111
# 128
# 107
# 101
# 128
# 123
# 98
# 126
# 103

# %%
ds.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Little interest in work',
#        'Feeling hopeless  ', 'Feeling angry than usual', 'high energy',
#        'doing more risky things ', 'Feeling nervous', 'panic',
#        'Avoiding anxious situations  ', 'illnesses are not taken seriously ',
#        'Thoughts of hurting yourself?', 'Sleep prob affecting sleep quality',
#        'memory problems', 'repeated Unpleasant thoughts',
#        'Not feeling close to people ', 'felt alone', 'felt stressed',
#        'feeling sad', 'being myself', 'hard to have fun.', 'easily annoyed',
#        'lose temper', 'frequent anger', 'Lose temper', 'irritability problems',
#        'qnconfident', 'qnsleep', 'qntalk', 'thoughts duration', 'bothering',
#        'thoughts control', 'thoughts interference', 'Restlessleep',
#        'sleepsatisfaction', 'refreshment', 'diffallsleep', 'sleep quality',
#        'Stomach pain', 'Back pain', 'joints pain', 'awful might happen',
# ...

# %%
mania=ds[['Restlessleep','diffallsleep','sleepsatisfaction','Sleep prob affecting sleep quality',
          'qnconfident','qntalk','thoughts duration','bothering','thoughts control','repeated Unpleasant thoughts','Feeling angry than usual']]

# %%
x1=mania.sum(axis=1)

# %%
print(x1)
# Out:
# 0     18
# 1     23
# 2     18
# 3     21
# 4     23
#       ..
# 62    28
# 63    27
# 64    21
# 65    29
# 66    21
# Length: 67, dtype: int64

# %%
tot=0
for i in x1:
    tot=tot+i
    res1=tot/67

print(res1)
# Out:
# 21.47761194029851

# %%
man=[]
for i in range(len(x1)):
    if x1[i]>res1:
        man.append(i)

print("IDs with mania")
print(man)
# Out:
# IDs with mania
# [1, 4, 5, 9, 10, 11, 12, 15, 16, 20, 22, 27, 28, 29, 30, 33, 34, 37, 38, 44, 47, 51, 53, 54, 55, 56, 57, 62, 63, 65]

# %%
ds.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Little interest in work',
#        'Feeling hopeless  ', 'Feeling angry than usual', 'high energy',
#        'doing more risky things ', 'Feeling nervous', 'panic',
#        'Avoiding anxious situations  ', 'illnesses are not taken seriously ',
#        'Thoughts of hurting yourself?', 'Sleep prob affecting sleep quality',
#        'memory problems', 'repeated Unpleasant thoughts',
#        'Not feeling close to people ', 'felt alone', 'felt stressed',
#        'feeling sad', 'being myself', 'hard to have fun.', 'easily annoyed',
#        'lose temper', 'frequent anger', 'Lose temper', 'irritability problems',
#        'qnconfident', 'qnsleep', 'qntalk', 'thoughts duration', 'bothering',
#        'thoughts control', 'thoughts interference', 'Restlessleep',
#        'sleepsatisfaction', 'refreshment', 'diffallsleep', 'sleep quality',
#        'Stomach pain', 'Back pain', 'joints pain', 'awful might happen',
# ...

# %%
hypomania=ds[['qntalk','being myself','Thoughts of hurting yourself?','Feeling nervous','worried','panic']]

# %%
x2=hypomania.sum(axis=1)

# %%
print(x2)
# Out:
# 0     11
# 1     18
# 2      6
# 3     12
# 4     11
#       ..
# 62    18
# 63    18
# 64    14
# 65    20
# 66    13
# Length: 67, dtype: int64

# %%
tot=0
for i in x2:
    tot=tot+i
    res2=tot/67

print(res2)
# Out:
# 11.686567164179104

# %%
hyp=[]
for i in range(len(x2)):
    if x2[i]>res2:
        hyp.append(i)
print("IDs with hypomania")
print(hyp)
# Out:
# IDs with hypomania
# [1, 3, 5, 8, 9, 10, 11, 12, 14, 16, 18, 20, 21, 22, 24, 27, 29, 30, 34, 41, 43, 44, 45, 51, 53, 54, 55, 56, 60, 62, 63, 64, 65, 66]

# %%
ds.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Little interest in work',
#        'Feeling hopeless  ', 'Feeling angry than usual', 'high energy',
#        'doing more risky things ', 'Feeling nervous', 'panic',
#        'Avoiding anxious situations  ', 'illnesses are not taken seriously ',
#        'Thoughts of hurting yourself?', 'Sleep prob affecting sleep quality',
#        'memory problems', 'repeated Unpleasant thoughts',
#        'Not feeling close to people ', 'felt alone', 'felt stressed',
#        'feeling sad', 'being myself', 'hard to have fun.', 'easily annoyed',
#        'lose temper', 'frequent anger', 'Lose temper', 'irritability problems',
#        'qnconfident', 'qnsleep', 'qntalk', 'thoughts duration', 'bothering',
#        'thoughts control', 'thoughts interference', 'Restlessleep',
#        'sleepsatisfaction', 'refreshment', 'diffallsleep', 'sleep quality',
#        'Stomach pain', 'Back pain', 'joints pain', 'awful might happen',
# ...

# %%
MDE=ds[['feeling sad','Little interest in work','Restlessleep','diffallsleep','sleepsatisfaction','refreshment','Sleep prob affecting sleep quality','high energy','sleep quality','repeated Unpleasant thoughts','thoughts duration','bothering','thoughts control']]

# %%
x3=MDE.sum(axis=1)

# %%
print(x3)
# Out:
# 0     27
# 1     31
# 2     28
# 3     28
# 4     27
#       ..
# 62    38
# 63    38
# 64    28
# 65    33
# 66    30
# Length: 67, dtype: int64

# %%
tot=0
for i in x3:
    tot=tot+i
    res3=tot/67

print(res3)
# Out:
# 28.29850746268657

# %%
dep=[]
for i in range(len(x3)):
    if x3[i]>res3:
        dep.append(i)
print("IDs with Depression")
print(dep)
# Out:
# IDs with Depression
# [1, 5, 9, 11, 12, 14, 15, 20, 22, 24, 27, 28, 29, 33, 34, 35, 37, 38, 39, 44, 45, 47, 48, 49, 53, 54, 55, 57, 60, 62, 63, 65, 66]

# %% [markdown]
# # training DS

# %%
import pandas as pd
df=pd.read_csv("/content/Bipolarf.csv")

# %%
df
# Out:
#                Name  Age  Gender  Little interest in work  Feeling hopeless    \
# 0               Aaa   16  Female                        1                   2
# 1     Abhinivesh S    19    Male                        1                   1
# 2         Abhishek    15    Male                        1                   1
# 3         Abinaya S   16  Female                        3                   1
# 4         Abinaya S   19  Female                        1                   1
# ..              ...  ...     ...                      ...                 ...
# 62           Swetha   19  Female                        2                   2
# 63          Varsha    17  Female                        3                   3
# 64    Vishnupriya.S   20  Female                        1                   1
# 65        Visruthi    17  Female                        2                   3
# 66  Visweswara S M    20    Male                        3                   1
#
# ...

# %%
df=df.drop(['Name'],axis=1)

# %%
x=df.iloc[:,:-1]
y=df["category"]

# %%
x
# Out:
#     Age  Gender  Little interest in work  Feeling hopeless    \
# 0    16  Female                        1                   2
# 1    19    Male                        1                   1
# 2    15    Male                        1                   1
# 3    16  Female                        3                   1
# 4    19  Female                        1                   1
# ..  ...     ...                      ...                 ...
# 62   19  Female                        2                   2
# 63   17  Female                        3                   3
# 64   20  Female                        1                   1
# 65   17  Female                        2                   3
# 66   20    Male                        3                   1
#
#     Feeling angry than usual  high energy  doing more risky things   \
# 0                          1            1                         2
# 1                          1            1                         1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df['category']=le.fit_transform(df['category'])

# %%
df['Gender'] = df['Gender'].astype(float)

# %%
df #3-n,2-m,0-d,1-h
# Out:
#     Age  Gender  Little interest in work  Feeling hopeless    \
# 0    16     0.0                        1                   2
# 1    19     1.0                        1                   1
# 2    15     1.0                        1                   1
# 3    16     0.0                        3                   1
# 4    19     0.0                        1                   1
# ..  ...     ...                      ...                 ...
# 62   19     0.0                        2                   2
# 63   17     0.0                        3                   3
# 64   20     0.0                        1                   1
# 65   17     0.0                        2                   3
# 66   20     1.0                        3                   1
#
#     Feeling angry than usual  high energy  doing more risky things   \
# 0                          1            1                         2
# 1                          1            1                         1
# ...

# %%
x=df.iloc[:,:-1]
y=df["category"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=43)

# %%
x_train.shape,x_test.shape
# Out:
# ((46, 46), (21, 46))

# %% [markdown]
# # **NAIVE** **BAYES**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
x_train
# Out:
#     Age  Gender  Little interest in work  Feeling hopeless    \
# 45   18     0.0                        2                   3
# 38   15     1.0                        2                   0
# 44   18     0.0                        1                   1
# 3    16     0.0                        3                   1
# 53   20     0.0                        2                   3
# 66   20     1.0                        3                   1
# 8    19     0.0                        1                   0
# 15   13     0.0                        3                   2
# 20   14     0.0                        2                   2
# 29   14     1.0                        2                   2
# 7    13     0.0                        1                   0
# 41   19     0.0                        2                   0
# 28   14     0.0                        2                   3
# 42   19     1.0                        3                   1
# ...

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
y_pred = gnb.predict(x_test)

# %%
from sklearn import metrics
print("accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# accuracy: 0.7142857142857143

# %% [markdown]
# # rfc

# %%
from sklearn.ensemble import RandomForestClassifier
class_rf=RandomForestClassifier(random_state=13,n_jobs=-1,max_depth=3,n_estimators=70,oob_score=True)
class_rf.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=70, n_jobs=-1, oob_score=True,
#                        random_state=13)

# %%
ypred=class_rf.predict(x_test)
ypred
# Out:
# array([3, 2, 0, 3, 2, 2, 2, 3, 2, 1, 3, 0, 2, 2, 2, 3, 2, 3, 2, 2, 2])

# %%
# %%time
class_rf.fit(x_train,y_train)
# Out:
# CPU times: user 168 ms, sys: 24.3 ms, total: 193 ms
# Wall time: 173 ms
# RandomForestClassifier(max_depth=3, n_estimators=70, n_jobs=-1, oob_score=True,
#                        random_state=13)

# %%
class_rf.oob_score_
# Out:
# 0.6739130434782609

# %%
# %%time
class_rf.fit(x_test,y_test)
# Out:
# CPU times: user 171 ms, sys: 17.9 ms, total: 189 ms
# Wall time: 170 ms
# RandomForestClassifier(max_depth=3, n_estimators=70, n_jobs=-1, oob_score=True,
#                        random_state=13)

# %%
class_rf.oob_score_
# Out:
# 0.6190476190476191

# %% [markdown]
# # DT

# %%
#decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
dt=DecisionTreeClassifier(criterion="gini",random_state=13)
dt=dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([3, 2, 3, 3, 2, 2, 2, 3, 2, 3, 3, 3, 2, 0, 2, 3, 2, 3, 2, 2, 2])

# %%
print("accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# accuracy: 0.6666666666666666

# %% [markdown]
# # Hyper Tuning

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
cv = RepeatedStratifiedKFold(n_splits=9, n_repeats=2, random_state=1)

# %%
from scipy.stats import loguniform
space=dict()
space['min_impurity_decrease'] = [0.0,0.1,0.4]
space['max_leaf_nodes'] = [2,3,4,5]
space['max_depth'] =[4,5,6,8,10]
space['random_state'] =[11,12,13]

# %%
from sklearn.model_selection import RandomizedSearchCV
search = RandomizedSearchCV(dt, space, n_iter=500, scoring='accuracy', n_jobs=-1, cv=cv, random_state=1,error_score='raise')
result = search.fit(x, y)
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 180 is smaller than n_iter=500. Running 180 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=9.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=9.
#   warnings.warn(
# Best Score: 0.6438492063492062
# Best Hyperparameters: {'random_state': 11, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': 2, 'max_depth': 4}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
cls = DecisionTreeClassifier(max_depth=4,max_leaf_nodes=2,min_impurity_decrease=0.0,random_state=11)
model = cls.fit(x_train,y_train)
model
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=2, random_state=11)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
ac=accuracy_score(y_test,y_pred)
cr=classification_report(y_test,y_pred)
print("Accuracy :",ac)
print(cr)
# Out:
# Accuracy : 0.6666666666666666
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00         2
#            2       0.73      0.89      0.80         9
#            3       0.67      1.00      0.80         6
#
#     accuracy                           0.67        21
#    macro avg       0.35      0.47      0.40        21
# weighted avg       0.50      0.67      0.57        21
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from scipy.stats import loguniform
spaces=dict()
spaces['min_impurity_decrease'] = [0.0,0.1,0.2,0.4]
spaces['max_leaf_nodes'] = [4,5,6,7]
spaces['max_depth'] =[1,2,3,4]
spaces['random_state']=[20,10,30]

# %%
from sklearn.model_selection import GridSearchCV
searchs = GridSearchCV(model, spaces, scoring='accuracy', n_jobs=-1, cv=cv,error_score='raise')

# %%
results = searchs.fit(x, y)
print('Best Score: %s' % results.best_score_)
print('Best Hyperparameters: %s' % results.best_params_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=9.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=9.
#   warnings.warn(
# Best Score: 0.6438492063492062
# Best Hyperparameters: {'max_depth': 1, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.0, 'random_state': 20}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
cls = DecisionTreeClassifier(max_depth=1,max_leaf_nodes=4,min_impurity_decrease=0.0,random_state=20)
model = cls.fit(x_train,y_train)
model
# Out:
# DecisionTreeClassifier(max_depth=1, max_leaf_nodes=4, random_state=20)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
ac=accuracy_score(y_test,y_pred)
cr=classification_report(y_test,y_pred)
print("Accuracy :",ac)
print(cr)
# Out:
# Accuracy : 0.6666666666666666
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00         2
#            2       0.73      0.89      0.80         9
#            3       0.67      1.00      0.80         6
#
#     accuracy                           0.67        21
#    macro avg       0.35      0.47      0.40        21
# weighted avg       0.50      0.67      0.57        21
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
pickle.dump(le,open("labelencod.pkl","wb"))
pickle.dump(dt,open("dectree.pkl","wb"))
